# %%
import json
import urllib2
from lxml import html
import re

# %%
url = "https://www.youtube.com/feed/trending"
response = urllib2.urlopen(url)
page = response.read()
tree = html.document_fromstring(page)
title = tree.cssselect('[class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink      spf-link "] ')
duration=tree.cssselect('[class="video-time"]')
user=tree.cssselect('[class="g-hovercard yt-uix-sessionlink       spf-link "]')
mydata = tree.cssselect('[class="yt-lockup-meta-info"] ' )
first_list=[]
for i in mydata:
    first_list.append(i.text_content())
data=str(first_list)

views=re.findall('\S([0-9]+\S*)\s+views',data)
second_list=[]
for i,z,a,b in zip(title,duration,user,views):
    second_list.append({'Title' :i.get("title"),"URL" : "https://www.youtube.com"+str(i.get('href')),'Duration':z.text,"Username":a.text,"Views": b})
print(second_list)

with open('trending_urllib.json', 'w') as output:
    json.dump(second_list, output, sort_keys = True, indent = 4)


import unicodecsv as csv

with open('trending_urllib_.csv', 'w') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(["Title", "URL", "Username", "Duration", "Views"])
    for i in data1:
        writer.writerow([i['Title'],i['URL'],i['Username'],i['Duration'],i['Views']])
# Out:
# [{'URL': 'https://www.youtube.com/watch?v=2QKg5SZ_35I', 'Duration': '2:46', 'Username': 'Sony Pictures Entertainment', 'Views': '3,541,349', 'Title': 'JUMANJI: WELCOME TO THE JUNGLE - Official Trailer (HD)'}, {'URL': 'https://www.youtube.com/watch?v=1sYF1SXcWqQ', 'Duration': '1:57', 'Username': 'Marvel Entertainment', 'Views': '3,747,125', 'Title': "Marvel's Inhumans - Official Trailer 1"}, {'URL': 'https://www.youtube.com/watch?v=kFQUlA-G0N4', 'Duration': '18:41', 'Username': 'CinemaSins', 'Views': '1,740,959', 'Title': 'Everything Wrong With Despicable Me 2 In 16 Minutes Or Less'}, {'URL': 'https://www.youtube.com/watch?v=nIJ0qhfQ_Hc', 'Duration': '5:13', 'Username': 'Liza Koshy', 'Views': '3,187,946', 'Title': "READING MEAN COMMENTS!! I'LL BE OKAY!"}, {'URL': 'https://www.youtube.com/watch?v=gvxNaSIB_WI', 'Duration': '8:46', 'Username': 'Conagh Kathleen', 'Views': '60,799', 'Title': 'Death Note | Official Trailer [HD] | Netflix'}, {'URL': 'https://www.youtube.com/watch?v=GO9JMR2m8
# ...

# %%
import json

with open('trending_urllib.json') as json_data:
    new_file = json.load(json_data)
from pprint import*
pprint(new_file)
# Out:
# [{u'Duration': u'2:46',
#   u'Title': u'JUMANJI: WELCOME TO THE JUNGLE - Official Trailer (HD)',
#   u'URL': u'https://www.youtube.com/watch?v=2QKg5SZ_35I',
#   u'Username': u'Sony Pictures Entertainment',
#   u'Views': u'3,541,349'},
#  {u'Duration': u'1:57',
#   u'Title': u"Marvel's Inhumans - Official Trailer 1",
#   u'URL': u'https://www.youtube.com/watch?v=1sYF1SXcWqQ',
#   u'Username': u'Marvel Entertainment',
#   u'Views': u'3,747,125'},
#  {u'Duration': u'18:41',
#   u'Title': u'Everything Wrong With Despicable Me 2 In 16 Minutes Or Less',
#   u'URL': u'https://www.youtube.com/watch?v=kFQUlA-G0N4',
#   u'Username': u'CinemaSins',
#   u'Views': u'1,740,959'},
#  {u'Duration': u'5:13',
#   u'Title': u"READING MEAN COMMENTS!! I'LL BE OKAY!",
#   u'URL': u'https://www.youtube.com/watch?v=nIJ0qhfQ_Hc',
#   u'Username': u'Liza Koshy',
#   u'Views': u'3,187,946'},
#  {u'Duration': u'8:46',
#   u'Title': u'Death Note | Official Trailer [HD] | Netflix',
# ...
